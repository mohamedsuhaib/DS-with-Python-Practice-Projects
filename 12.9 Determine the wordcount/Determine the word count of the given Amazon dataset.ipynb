# %% [markdown]
# <img src="http://cfs22.simplicdn.net/ice9/new_logo.svgz "/>
#
# # Assignment 01: Determine the wordcount
#
# *The comments/sections provided are your cues to perform the assignment. You don't need to limit yourself to the number of rows/cells provided. You can add additional rows in each section to add more lines of code.*
#
# *If at any point in time you need help on solving this assignment, view our demo video to understand the different steps of the code.*
#
# **Happy coding!**
#
# * * *

# %% [markdown]
# ## Determine the word count of the given Amazon dataset:
# ### DESCRIPTION
#
# __Problem:__
#
# * Create a MapReduce program to determine the word count of the Amazon dataset.
# * Submit the MapReduce task to HDFS and run it.
# * Verify the output.

# %% [markdown]
# #### Create a MapReduce program to determine the word count of the Amazon dataset

# %% [markdown]
# ##### Copy the Dataset to Home Directory
# * Copy the Amzon_text_dataset to cloudera Home Directory.
# * Open the Terminal Application.
# * Enter "ls -lrt" to list the folders and files in Home directory.
#
# ![Capture1.PNG](attachment:Capture1.PNG)

# %% [markdown]
# ##### View the Dataset
# * View the dataset using "cat Amazon_text_data" command.
#
# ![Capture2.PNG](attachment:Capture2.PNG)

# %% [markdown]
# ##### Create the Mapper code
# * Create mapper python program in Vi editor using "Vi mapper.py" command.
# * Use "cat mapper.py" to view the contents of the file.
# ![Capture3.PNG](attachment:Capture3.PNG)

# %% [markdown]
# ##### Create the Reducer code
# * Create reducer python program in Vi editor using "Vi reducer.py" command.
# * Use "cat reducer.py" to view the contents of the file.
#
# ![Capture4.PNG](attachment:Capture4.PNG)

# %% [markdown]
# ##### Execute the Mapper program over the Amazon_text_dataset
# * Use "cat Amazon_text_dataset | python mapper.py" commant to execute the Mapper program over the Amazon_text_dataset.
#
# ![Capture5.PNG](attachment:Capture5.PNG)

# %% [markdown]
# #### Submit the MapReduce task to HDFS and run it.
# ##### Copy the Amazon_text_dataset file to HDFS location
#
# * Use "hdfs dfs -put Amazon_text_dataset /user/cloudera" to copy the "Amazon_text_dataset" to HDFS location.
# * Use "hdfs dfs -ls /user/cloudera" to list the folders and files in HDFS location.
#
# ![Capture6.PNG](attachment:Capture6.PNG)

# %% [markdown]
# ##### Submit the MapReduce Task
# * Using below command, sumbit the MapReduce task, add the below line in bash.
# * Once the task is submitted, it runs the mapper first and then rins the reducer program over the dataset.
#
# **hadoop jar /usr/lib/hadoop-mapreduce/hadoop-streaming.jar -file /home/cloudera/mapper.py /home/cloudera/reducer.py -mapper "python mapper.py" -reducer "python reducer.py" -input /user/cloudera/Amazon_text_dataset -output /user/cloudera/wc_output06**
#
# ![Capture7.PNG](attachment:Capture7.PNG)

# %% [markdown]
# ![Capture8.PNG](attachment:Capture8.PNG)

# %% [markdown]
# #### Verify the output
# * Verify the output folder present in HDFS loacation  using below command.
#     * hdfs dfs -ls /user/clouder

# %% [markdown]
# ![Capture9.PNG](attachment:Capture9.PNG)

# %% [markdown]
# * To check the Output on HDFS use the below comment.
#     * hdfs dfs -ls /user/cloudera/wc_output06

# %% [markdown]
# ![Capture10.PNG](attachment:Capture10.PNG)

# %% [markdown]
# * To View the part file use below command
#     * hdfs dfs -cat /user/cloudera/wc_output06/part*

# %% [markdown]
# ![Capture11.PNG](attachment:Capture11.PNG)
