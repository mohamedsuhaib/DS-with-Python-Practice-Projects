# %% [markdown]
# <img src="http://cfs22.simplicdn.net/ice9/new_logo.svgz "/>
#
# # Assignment 02: Create, Filter, and Clean an RDD
#
# *The comments/sections provided are your cues to perform the assignment. You don't need to limit yourself to the number of rows/cells provided. You can add additional rows in each section to add more lines of code.*
#
# *If at any point in time you need help on solving this assignment, view our demo video to understand the different steps of the code.*
#
# **Happy coding!**
#
# * * *

# %% [markdown]
# ## Display all the airports based in New York using PySpark
# __DESCRIPTION__
#
# __Problem:__
#
# Use the given dataset to count and display all the airports based in New York using PySpark. Perform the following steps:
#
#     View all the airports listed in the dataset
#     View only the first 10 records
#     Filter the data for all airports located in New York
#     Clean up the dataset, if required
#
# You can download the additional resources from the link shared - https://www.dropbox.com/sh/99zzg0rn5ekhir5/AACfmgTPUfJI8GuG9LCe2PLSa?dl=0

# %% [markdown]
# #### 1: Perform the preparatory activities

# %%
#Verify the Spark Context  
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
#Import the given airport dataset
datafile = sc.textFile('D:\\NIPUN_SC_REC\\3_Practice_Project\\Course_5_Data Science with Python\\Practice_projects\\Lesson 12.11_practice project\\Airport.csv')

# %% [markdown]
# #### 2: View all the airports listed in the dataset

# %%
#collect() returns all elements of the dataset as an array
datafile.collect()
# Out:
# ['Code,Description',
#  '"01A","Afognak Lake, AK: Afognak Lake Airport"',
#  '"03A","Granite Mountain, AK: Bear Creek Mining Strip"',
#  '"04A","Lik, AK: Lik Mining Camp"',
#  '"05A","Little Squaw, AK: Little Squaw Airport"',
#  '"06A","Kizhuyak, AK: Kizhuyak Bay"',
#  '"07A","Klawock, AK: Klawock Seaplane Base"',
#  '"08A","Elizabeth Island, AK: Elizabeth Island Airport"',
#  '"09A","Homer, AK: Augustin Island"',
#  '"1B1","Hudson, NY: Columbia County"',
#  '"1G4","Peach Springs, AZ: Grand Canyon West"',
#  '"1N7","Blairstown, NJ: Blairstown Airport"',
#  '"1NY","Penn Yan, NY: Penn Yan Airport"',
#  '"6B0","Middlebury, VT: Middlebury State"',
#  '"7AK","Akun, AK: Akun Airport"',
#  '"8F3","Crosbyton, TX: Crosbyton Municipal"',
#  '"A01","Fairbanks/Ft. Wainwright, AK: Blair Lake"',
#  '"A02","Deadmans Bay, AK: Deadmans Bay Airport"',
#  '"A03","Hallo Bay, AK: Hallo Bay Airport"',
#  '"A04","Red Lake, AK: Red Lake Airport"',
#  '"A05","Shell Lake, AK: Shell Lake Airport"',
# ...

# %%
#count() returns the number of elements present in the dataset
datafile.count()
# Out:
# 6389

# %% [markdown]
# #### 3: View only the first 10 records

# %%
#take(n) returns number of elements(n) as specified by the number in parenthesis.
datafile.take(10)
# Out:
# ['Code,Description',
#  '"01A","Afognak Lake, AK: Afognak Lake Airport"',
#  '"03A","Granite Mountain, AK: Bear Creek Mining Strip"',
#  '"04A","Lik, AK: Lik Mining Camp"',
#  '"05A","Little Squaw, AK: Little Squaw Airport"',
#  '"06A","Kizhuyak, AK: Kizhuyak Bay"',
#  '"07A","Klawock, AK: Klawock Seaplane Base"',
#  '"08A","Elizabeth Island, AK: Elizabeth Island Airport"',
#  '"09A","Homer, AK: Augustin Island"',
#  '"1B1","Hudson, NY: Columbia County"']

# %% [markdown]
# #### 4: Filter the data for all airports located in New York

# %%
#Use New York state (NY) code to filter the required data
NY_code_filter  = datafile.filter(lambda x:'NY' in x)

# %%
#Verify the total number of airports present in the filtered list
NY_code_filter.count()
# Out:
# 81

# %%
#View all the details of the airports in the filtered list 
NY_code_filter.collect()
# Out:
# ['"1B1","Hudson, NY: Columbia County"',
#  '"1NY","Penn Yan, NY: Penn Yan Airport"',
#  '"ALB","Albany, NY: Albany International"',
#  '"ART","Watertown, NY: Watertown International"',
#  '"AXB","Alexandria Bay, NY: Maxson Airfield"',
#  '"BGM","Binghamton, NY: Greater Binghamton/Edwin A. Link Field"',
#  '"BUF","Buffalo, NY: Buffalo Niagara International"',
#  '"CNY","Moab, UT: Canyonlands Field"',
#  '"CTO","Calverton, NY: Calverton Executive Airpark"',
#  '"CTX","Cortland, NY: Cortland County Chase Field"',
#  '"DKK","Dunkirk, NY: Chautauqua County/Dunkirk"',
#  '"DQK","Fort Drum, NY: Wheeler-Sack AAF"',
#  '"ELM","Elmira/Corning, NY: Elmira/Corning Regional"',
#  '"FID","Fishers Island, NY: Elizabeth Field"',
#  '"FLU","New York, NY: Flushing"',
#  '"FOK","Westhampton, NY: Francis S. Gabreski"',
#  '"FRG","East Farmingdale, NY: Republic"',
#  '"GFL","Glens Falls, NY: Floyd Bennett Memorial"',
#  '"GVQ","Batavia, NY: Genesee County"',
# ...

# %% [markdown]
# #### 5: Clean up the dataset (Hint: Identify and use the common factor among all the airports that are located in New York)

# %%
#Update the filter condition to get the required output
NY_Airports = NY_code_filter.filter(lambda x:', NY' in x)

# %%
#Verify the total number of airports present in the new filtered list
NY_Airports.count()
# Out:
# 70

# %%
#View the contents of the new filtered list
NY_Airports.collect()
# Out:
# ['"1B1","Hudson, NY: Columbia County"',
#  '"1NY","Penn Yan, NY: Penn Yan Airport"',
#  '"ALB","Albany, NY: Albany International"',
#  '"ART","Watertown, NY: Watertown International"',
#  '"AXB","Alexandria Bay, NY: Maxson Airfield"',
#  '"BGM","Binghamton, NY: Greater Binghamton/Edwin A. Link Field"',
#  '"BUF","Buffalo, NY: Buffalo Niagara International"',
#  '"CTO","Calverton, NY: Calverton Executive Airpark"',
#  '"CTX","Cortland, NY: Cortland County Chase Field"',
#  '"DKK","Dunkirk, NY: Chautauqua County/Dunkirk"',
#  '"DQK","Fort Drum, NY: Wheeler-Sack AAF"',
#  '"ELM","Elmira/Corning, NY: Elmira/Corning Regional"',
#  '"FID","Fishers Island, NY: Elizabeth Field"',
#  '"FLU","New York, NY: Flushing"',
#  '"FOK","Westhampton, NY: Francis S. Gabreski"',
#  '"FRG","East Farmingdale, NY: Republic"',
#  '"GFL","Glens Falls, NY: Floyd Bennett Memorial"',
#  '"GVQ","Batavia, NY: Genesee County"',
#  '"HPN","White Plains, NY: Westchester County"',
# ...
